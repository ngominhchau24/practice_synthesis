# %%
import sys
import os
# Get the current working directory
current_dir = os.getcwd()

main_file_path = os.path.join(current_dir,'/content/drive/MyDrive/Synthesis/SynthesisLab1')
sys.path.append(main_file_path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from __future__ import annotations
import sys
from typing import List, Optional
from truth_table import (
    parse_sum_of_minterms_file,
    build_outputs_from_minterm_indices,
    print_truth_table_markdown,
    generate_random_spec_file,
)
from cover import select_cover_for_one_output
from pla import build_full_pla
from main import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4086232845.py in <cell line: 0>()
#       2 import sys
#       3 from typing import List, Optional
# ----> 4 from truth_table import (
#       5     parse_sum_of_minterms_file,
#       6     build_outputs_from_minterm_indices,
#
# ModuleNotFoundError: No module named 'truth_table'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !python3 main.py random
# !echo "=========================="
# !cat random_spec.txt
# Out:
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory
# ==========================
# cat: random_spec.txt: No such file or directory
